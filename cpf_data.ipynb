# %% [markdown]
# # IUCN red list
#
# - estimates of how at-risk species are of going extinct
# - discrete levels ('redlistCategory' in the data')

# %%
import pandas as pd
animal_iucn = pd.read_csv('animal_iucn.csv')

# %%
animal_iucn.head()
# Out:
#    assessmentId  internalTaxonId           scientificName kingdomName  \
# 0        495630            10030        Hexanchus griseus    ANIMALIA
# 1        495907            10041      Heosemys annandalii    ANIMALIA
# 2        497499        132523146         Hubbsina turneri    ANIMALIA
# 3        497550            10267  Hungerfordia pelewensis    ANIMALIA
# 4        498370            10767      Ictalurus australis    ANIMALIA
#
#   phylumName           orderName       className       familyName  \
# 0   CHORDATA      HEXANCHIFORMES  CHONDRICHTHYES      HEXANCHIDAE
# 1   CHORDATA          TESTUDINES        REPTILIA      GEOEMYDIDAE
# 2   CHORDATA  CYPRINODONTIFORMES  ACTINOPTERYGII        GOODEIDAE
# 3   MOLLUSCA   ARCHITAENIOGLOSSA      GASTROPODA  DIPLOMMATINIDAE
# 4   CHORDATA        SILURIFORMES  ACTINOPTERYGII      ICTALURIDAE
#
#       genusName speciesName  infraType  infraName  infraAuthority  \
# 0     Hexanchus     griseus        NaN        NaN             NaN
# ...

# %% [markdown]
# # Amniote life histories
#
# - similar measurements as pantheria, but across birds and reptiles too
# - dealing with the species names ('taxonomy') is a little tricky (Nathan will demonstrate)

# %%
Amniote_db = pd.read_csv('Amniote_Database_Aug_2015.csv')
Amniote_db.head()
# Out:
#   class            order        family      genus      species  subspecies  \
# 0  Aves  Accipitriformes  Accipitridae  Accipiter  albogularis        -999
# 1  Aves  Accipitriformes  Accipitridae  Accipiter       badius        -999
# 2  Aves  Accipitriformes  Accipitridae  Accipiter      bicolor        -999
# 3  Aves  Accipitriformes  Accipitridae  Accipiter   brachyurus        -999
# 4  Aves  Accipitriformes  Accipitridae  Accipiter     brevipes        -999
#
#                common_name  female_maturity_d  litter_or_clutch_size_n  \
# 0             Pied Goshawk           -999.000                  -999.00
# 1                   Shikra            363.468                     3.25
# 2           Bicolored Hawk           -999.000                     2.70
# 3  New Britain Sparrowhawk           -999.000                  -999.00
# 4       Levant Sparrowhawk            363.468                     4.00
#
#    litters_or_clutches_per_y  ...  egg_length_mm  fledging_mass_g  \
# ...

# %% [markdown]
# # GBIF (Global Biodiversity Information Facility)
#
# - information about what species occur in different geographic areas
# - you will also need to take some steps with the 'taxonomy'

# %%
gbif = pd.read_csv("GBIF_east_africa.csv",sep="\t")
gbif.head()
# Out:
#    taxonKey                         scientificName  acceptedTaxonKey  \
# 0       341                            Turbellaria             341.0
# 1      2390                       Scrophulariaceae            2390.0
# 2      4334                                 Apidae            4334.0
# 3   1033975                 Enochrus Thomson, 1859         1033975.0
# 4   1055329  Ablaberoides emeritus Péringuey, 1904         1055329.0
#
#                   acceptedScientificName  numberOfOccurrences taxonRank  \
# 0                            Turbellaria                  297     CLASS
# 1                       Scrophulariaceae                   86    FAMILY
# 2                                 Apidae                   39    FAMILY
# 3                 Enochrus Thomson, 1859                   47     GENUS
# 4  Ablaberoides emeritus Péringuey, 1904                    6   SPECIES
#
#   taxonomicStatus   kingdom  kingdomKey           phylum  ...  classKey  \
# ...

# %%
gbif_species = gbif[gbif['taxonRank']=="SPECIES"]
gbif_species.head()
# Out:
#    taxonKey                                     scientificName  \
# 4   1055329              Ablaberoides emeritus Péringuey, 1904
# 5   1076733  Heterophana canaliculata (Gory & Percheron, 1833)
# 6   1081449              Mecynorhina harrisii (Westwood, 1847)
# 7   1081652                     Pachnoda aemula Bourgoin, 1919
# 8   1091194           Onthophagus quadrinodosus Fåhraeus, 1857
#
#    acceptedTaxonKey                             acceptedScientificName  \
# 4         1055329.0              Ablaberoides emeritus Péringuey, 1904
# 5         1076733.0  Heterophana canaliculata (Gory & Percheron, 1833)
# 6         1081449.0              Mecynorhina harrisii (Westwood, 1847)
# 7         1081651.0                  Pachnoda fissipuncta Kraatz, 1885
# 8         1091194.0           Onthophagus quadrinodosus Fåhraeus, 1857
#
#    numberOfOccurrences taxonRank taxonomicStatus   kingdom  kingdomKey  \
# 4                    6   SPECIES        ACCEPTED  Animalia           1
# ...
